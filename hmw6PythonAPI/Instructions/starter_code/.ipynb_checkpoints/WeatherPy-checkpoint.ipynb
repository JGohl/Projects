# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 634

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
temp = []
wind_speed = []
cloud = []
country = []
date = []
humidity = []
lat = []
lon = []
max_temp = []
city_list = []

city_record_count = 0
city_count = 0
set_count = 1
print("Beginning Data Retrieval")
print('-------------------------------')

for city in cities:
    response = requests.get(query_url + city).json()
    try:
        city_record_count += 1
        city_list.append(response['name'])
        temp.append(response['main']['temp'])
        wind_speed.append(response['wind']['speed'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        print('Processessing Record ' + str(city_record_count) + " of Set " + str(set_count) + " | " + city)
        if city_record_count == 50:
            city_record_count = 0
            set_count += 1
            city_count += 1
    except KeyError:
        city_record_count -= 1
        print(city + ' not found. Skipping...')
    except ConnectionError:
        print("Connection Error")
        continue
    except ProtocalError:
        print("Protocal Error")
        continue
            
print('-------------------------------')
print('Data Retrieval Complete')
print('-------------------------------')
# Out:
# Beginning Data Retrieval
# -------------------------------
# attawapiskat not found. Skipping...
# Processessing Record 1 of Set 1 | jamestown
# taolanaro not found. Skipping...
# Processessing Record 2 of Set 1 | mataura
# Processessing Record 3 of Set 1 | lagoa
# Processessing Record 4 of Set 1 | barranca
# Processessing Record 5 of Set 1 | busselton
# Processessing Record 6 of Set 1 | rikitea
# Processessing Record 7 of Set 1 | thompson
# Processessing Record 8 of Set 1 | kahului
# Processessing Record 9 of Set 1 | albany
# Processessing Record 10 of Set 1 | saint-louis
# Processessing Record 11 of Set 1 | sioux lookout
# Processessing Record 12 of Set 1 | bluff
# Processessing Record 13 of Set 1 | tuktoyaktuk
# Processessing Record 14 of Set 1 | klyuchevskiy
# Processessing Record 15 of Set 1 | vaini
# Processessing Record 16 of Set 1 | taoudenni
# lolua not found. Skipping...
# Processessing Record 17 of Set 1 | constitucion
# mys shmidta not found. Skipping...
# Processessing Record 18 of Set 1 | mar del plata
# Processessing Record 19 of Set 1 | hobart
# Processessing Record 20 of Set 1 | punta arenas
# Processessing Record 21 of Set 1 | ilulissat
# Processessing Record 22 of Set 1 | kapaa
# Processessing Record 23 of Set 1 | gualeguaychu
# Processessing Record 24 of Set 1 | mamanguape
# Processessing Record 25 of Set 1 | puerto ayora
# Processessing Record 26 of Set 1 | new norfolk
# Processessing Record 27 of Set 1 | evensk
# Processessing Record 28 of Set 1 | nanortalik
# Processessing Record 29 of Set 1 | ust-tsilma
# Processessing Record 30 of Set 1 | yellowknife
# Processessing Record 31 of Set 1 | tautira
# Processessing Record 32 of Set 1 | qaanaaq
# Processessing Record 33 of Set 1 | paamiut
# Processessing Record 34 of Set 1 | carnarvon
# Processessing Record 35 of Set 1 | calbuco
# Processessing Record 36 of Set 1 | socoltenango
# Processessing Record 37 of Set 1 | ushuaia
# Processessing Record 38 of Set 1 | dingzhou
# tsihombe not found. Skipping...
# Processessing Record 39 of Set 1 | nikolskoye
# Processessing Record 40 of Set 1 | hermanus
# saleaula not found. Skipping...
# Processessing Record 41 of Set 1 | vad
# Processessing Record 42 of Set 1 | san quintin
# Processessing Record 43 of Set 1 | salalah
# Processessing Record 44 of Set 1 | avarua
# Processessing Record 45 of Set 1 | shingu
# Processessing Record 46 of Set 1 | ostrovnoy
# Processessing Record 47 of Set 1 | isesaki
# Processessing Record 48 of Set 1 | khandyga
# Processessing Record 49 of Set 1 | hithadhoo
# Processessing Record 50 of Set 1 | torbay
# bengkulu not found. Skipping...
# Processessing Record 1 of Set 2 | lydenburg
# Processessing Record 2 of Set 2 | leningradskiy
# Processessing Record 3 of Set 2 | morazan
# Processessing Record 4 of Set 2 | aracati
# Processessing Record 5 of Set 2 | grand baie
# Processessing Record 6 of Set 2 | kiunga
# Processessing Record 7 of Set 2 | qaqortoq
# Processessing Record 8 of Set 2 | alakurtti
# Processessing Record 9 of Set 2 | san ramon
# Processessing Record 10 of Set 2 | ponta do sol
# achisay not found. Skipping...
# jabiru not found. Skipping...
# Processessing Record 11 of Set 2 | inhambane
# Processessing Record 12 of Set 2 | pathalgaon
# Processessing Record 13 of Set 2 | bang saphan
# Processessing Record 14 of Set 2 | north bend
# Processessing Record 15 of Set 2 | mahebourg
# Processessing Record 16 of Set 2 | dauriya
# Processessing Record 17 of Set 2 | chapais
# daxian not found. Skipping...
# arrecife not found. Skipping...
# Processessing Record 18 of Set 2 | butaritari
# Processessing Record 19 of Set 2 | arraial do cabo
# Processessing Record 20 of Set 2 | filadelfia
# Processessing Record 21 of Set 2 | cherskiy
# Processessing Record 22 of Set 2 | khatanga
# Processessing Record 23 of Set 2 | moose factory
# Processessing Record 24 of Set 2 | haines junction
# barentsburg not found. Skipping...
# Processessing Record 25 of Set 2 | bathsheba
# Processessing Record 26 of Set 2 | norman wells
# Processessing Record 27 of Set 2 | sfantu gheorghe
# Processessing Record 28 of Set 2 | saravena
# Processessing Record 29 of Set 2 | porto walter
# Processessing Record 30 of Set 2 | saint george
# Processessing Record 31 of Set 2 | bukama
# Processessing Record 32 of Set 2 | udachnyy
# Processessing Record 33 of Set 2 | loralai
# Processessing Record 34 of Set 2 | leland
# gogrial not found. Skipping...
# Processessing Record 35 of Set 2 | lebrija
# Processessing Record 36 of Set 2 | alofi
# marcona not found. Skipping...
# Processessing Record 37 of Set 2 | aklavik
# Processessing Record 38 of Set 2 | batticaloa
# Processessing Record 39 of Set 2 | chokurdakh
# Processessing Record 40 of Set 2 | mount gambier
# Processessing Record 41 of Set 2 | clinton
# Processessing Record 42 of Set 2 | pevek
# Processessing Record 43 of Set 2 | kuruman
# Processessing Record 44 of Set 2 | karaton
# Processessing Record 45 of Set 2 | atuona
# Processessing Record 46 of Set 2 | zavodouspenskoye
# Processessing Record 47 of Set 2 | bhandara
# Processessing Record 48 of Set 2 | raudeberg
# Processessing Record 49 of Set 2 | mitsamiouli
# Processessing Record 50 of Set 2 | belmonte
# Processessing Record 1 of Set 3 | kultuk
# Processessing Record 2 of Set 3 | orcopampa
# Processessing Record 3 of Set 3 | barrow
# Processessing Record 4 of Set 3 | hilo
# Processessing Record 5 of Set 3 | broome
# Processessing Record 6 of Set 3 | paso de los toros
# Processessing Record 7 of Set 3 | ahipara
# Processessing Record 8 of Set 3 | sitka
# Processessing Record 9 of Set 3 | beringovskiy
# Processessing Record 10 of Set 3 | saint-philippe
# Processessing Record 11 of Set 3 | maltahohe
# Processessing Record 12 of Set 3 | loikaw
# Processessing Record 13 of Set 3 | bredasdorp
# Processessing Record 14 of Set 3 | coihueco
# Processessing Record 15 of Set 3 | kapuskasing
# Processessing Record 16 of Set 3 | komsomolskiy
# Processessing Record 17 of Set 3 | xinpu
# Processessing Record 18 of Set 3 | saskylakh
# Processessing Record 19 of Set 3 | naryan-mar
# Processessing Record 20 of Set 3 | saint-lo
# Processessing Record 21 of Set 3 | cayenne
# Processessing Record 22 of Set 3 | bambous virieux
# pietarsaari not found. Skipping...
# Processessing Record 23 of Set 3 | laguna
# Processessing Record 24 of Set 3 | santa cruz
# Processessing Record 25 of Set 3 | kaeo
# Processessing Record 26 of Set 3 | ula
# Processessing Record 27 of Set 3 | aberdeen
# Processessing Record 28 of Set 3 | harjavalta
# Processessing Record 29 of Set 3 | kumluca
# Processessing Record 30 of Set 3 | pisco
# Processessing Record 31 of Set 3 | namibe
# Processessing Record 32 of Set 3 | tasiilaq
# Processessing Record 33 of Set 3 | hobyo
# kuche not found. Skipping...
# illoqqortoormiut not found. Skipping...
# Processessing Record 34 of Set 3 | tanout
# Processessing Record 35 of Set 3 | aitape
# Processessing Record 36 of Set 3 | pangnirtung
# Processessing Record 37 of Set 3 | dongsheng
# Processessing Record 38 of Set 3 | liverpool
# Processessing Record 39 of Set 3 | iqaluit
# Processessing Record 40 of Set 3 | sola
# Processessing Record 41 of Set 3 | georgetown
# Processessing Record 42 of Set 3 | tuatapere
# Processessing Record 43 of Set 3 | puerto madryn
# Processessing Record 44 of Set 3 | touros
# Processessing Record 45 of Set 3 | saldanha
# Processessing Record 46 of Set 3 | kodiak
# betioky not found. Skipping...
# Processessing Record 47 of Set 3 | east london
# Processessing Record 48 of Set 3 | kutum
# Processessing Record 49 of Set 3 | sinnamary
# Processessing Record 50 of Set 3 | langgons
# ijaki not found. Skipping...
# Processessing Record 1 of Set 4 | khorinsk
# Processessing Record 2 of Set 4 | ribeira grande
# Processessing Record 3 of Set 4 | port alfred
# Processessing Record 4 of Set 4 | iranshahr
# Processessing Record 5 of Set 4 | banting
# Processessing Record 6 of Set 4 | ancud
# yirol not found. Skipping...
# Processessing Record 7 of Set 4 | fairbanks
# samusu not found. Skipping...
# Processessing Record 8 of Set 4 | tosya
# Processessing Record 9 of Set 4 | bulgan
# Processessing Record 10 of Set 4 | faanui
# Processessing Record 11 of Set 4 | morondava
# Processessing Record 12 of Set 4 | gornyy
# Processessing Record 13 of Set 4 | francistown
# Processessing Record 14 of Set 4 | victoria
# Processessing Record 15 of Set 4 | sept-iles
# Processessing Record 16 of Set 4 | bayir
# Processessing Record 17 of Set 4 | la rioja
# Processessing Record 18 of Set 4 | provideniya
# Processessing Record 19 of Set 4 | honiara
# Processessing Record 20 of Set 4 | kapit
# amderma not found. Skipping...
# Processessing Record 21 of Set 4 | grindavik
# Processessing Record 22 of Set 4 | nemuro
# Processessing Record 23 of Set 4 | lavrentiya
# Processessing Record 24 of Set 4 | male
# Processessing Record 25 of Set 4 | harer
# Processessing Record 26 of Set 4 | cidreira
# Processessing Record 27 of Set 4 | pechenga
# Processessing Record 28 of Set 4 | maniitsoq
# Processessing Record 29 of Set 4 | pavilosta
# Processessing Record 30 of Set 4 | rocha
# Processessing Record 31 of Set 4 | severo-kurilsk
# Processessing Record 32 of Set 4 | hambantota
# tarudant not found. Skipping...
# Processessing Record 33 of Set 4 | yumen
# Processessing Record 34 of Set 4 | necochea
# Processessing Record 35 of Set 4 | sorong
# Processessing Record 36 of Set 4 | souillac
# Processessing Record 37 of Set 4 | mount isa
# Processessing Record 38 of Set 4 | comodoro rivadavia
# Processessing Record 39 of Set 4 | chuy
# belushya guba not found. Skipping...
# Processessing Record 40 of Set 4 | xinyang
# Processessing Record 41 of Set 4 | mogadishu
# Processessing Record 42 of Set 4 | vestmanna
# tasbuget not found. Skipping...
# Processessing Record 43 of Set 4 | yunhe
# rungata not found. Skipping...
# Processessing Record 44 of Set 4 | port elizabeth
# Processessing Record 45 of Set 4 | vardo
# Processessing Record 46 of Set 4 | castro
# Processessing Record 47 of Set 4 | oriximina
# Processessing Record 48 of Set 4 | san patricio
# Processessing Record 49 of Set 4 | peachland
# Processessing Record 50 of Set 4 | vaitape
# Processessing Record 1 of Set 5 | kanadukathan
# Processessing Record 2 of Set 5 | san cristobal
# Processessing Record 3 of Set 5 | lima
# Processessing Record 4 of Set 5 | lompoc
# Processessing Record 5 of Set 5 | port lincoln
# burica not found. Skipping...
# Processessing Record 6 of Set 5 | guerrero negro
# Processessing Record 7 of Set 5 | esperance
# Processessing Record 8 of Set 5 | yar-sale
# Processessing Record 9 of Set 5 | ano mera
# olafsvik not found. Skipping...
# vaitupu not found. Skipping...
# Processessing Record 10 of Set 5 | halifax
# malakal not found. Skipping...
# Processessing Record 11 of Set 5 | puerto escondido
# Processessing Record 12 of Set 5 | abashiri
# Processessing Record 13 of Set 5 | sao filipe
# Processessing Record 14 of Set 5 | matara
# Processessing Record 15 of Set 5 | fort morgan
# Processessing Record 16 of Set 5 | arroyo
# uk not found. Skipping...
# Processessing Record 17 of Set 5 | aviles
# Processessing Record 18 of Set 5 | macusani
# Processessing Record 19 of Set 5 | samarai
# Processessing Record 20 of Set 5 | bolshoye nagatkino
# Processessing Record 21 of Set 5 | tevaitoa
# Processessing Record 22 of Set 5 | poum
# Processessing Record 23 of Set 5 | yaan
# Processessing Record 24 of Set 5 | lorengau
# Processessing Record 25 of Set 5 | manono
# Processessing Record 26 of Set 5 | columbia
# Processessing Record 27 of Set 5 | malaga
# Processessing Record 28 of Set 5 | salinopolis
# Processessing Record 29 of Set 5 | mochudi
# Processessing Record 30 of Set 5 | libreville
# Processessing Record 31 of Set 5 | cape town
# Processessing Record 32 of Set 5 | clyde river
# Processessing Record 33 of Set 5 | lasem
# kota bahru not found. Skipping...
# Processessing Record 34 of Set 5 | longyearbyen
# Processessing Record 35 of Set 5 | warri
# Processessing Record 36 of Set 5 | kingussie
# Processessing Record 37 of Set 5 | yulara
# mahadday weyne not found. Skipping...
# Processessing Record 38 of Set 5 | airai
# Processessing Record 39 of Set 5 | belaya gora
# Processessing Record 40 of Set 5 | blagoyevo
# Processessing Record 41 of Set 5 | gavardo
# Processessing Record 42 of Set 5 | harper
# Processessing Record 43 of Set 5 | namtsy
# Processessing Record 44 of Set 5 | upernavik
# hihifo not found. Skipping...
# Processessing Record 45 of Set 5 | misratah
# Processessing Record 46 of Set 5 | vila franca do campo
# Processessing Record 47 of Set 5 | coihaique
# Processessing Record 48 of Set 5 | albion
# Processessing Record 49 of Set 5 | acapulco
# Processessing Record 50 of Set 5 | tucumcari
# Processessing Record 1 of Set 6 | nhulunbuy
# Processessing Record 2 of Set 6 | lebu
# Processessing Record 3 of Set 6 | dikson
# Processessing Record 4 of Set 6 | foz
# Processessing Record 5 of Set 6 | ystad
# Processessing Record 6 of Set 6 | kailua
# Processessing Record 7 of Set 6 | wuda
# Processessing Record 8 of Set 6 | burgersdorp
# Processessing Record 9 of Set 6 | talcahuano
# Processessing Record 10 of Set 6 | camargo
# Processessing Record 11 of Set 6 | amahai
# Processessing Record 12 of Set 6 | alugan
# Processessing Record 13 of Set 6 | sumbe
# Processessing Record 14 of Set 6 | maceio
# Processessing Record 15 of Set 6 | kavieng
# Processessing Record 16 of Set 6 | daru
# Processessing Record 17 of Set 6 | adrar
# tantareni not found. Skipping...
# Processessing Record 18 of Set 6 | isangel
# Processessing Record 19 of Set 6 | portland
# monte cristi not found. Skipping...
# Processessing Record 20 of Set 6 | chornukhy
# Processessing Record 21 of Set 6 | vanavara
# Processessing Record 22 of Set 6 | fray bentos
# Processessing Record 23 of Set 6 | gambela
# Processessing Record 24 of Set 6 | riyadh
# Processessing Record 25 of Set 6 | avera
# mergui not found. Skipping...
# Processessing Record 26 of Set 6 | college
# urumqi not found. Skipping...
# Processessing Record 27 of Set 6 | mazara del vallo
# Processessing Record 28 of Set 6 | santa maria del oro
# tidore not found. Skipping...
# Processessing Record 29 of Set 6 | port hardy
# Processessing Record 30 of Set 6 | kanlagay
# Processessing Record 31 of Set 6 | cabo san lucas
# tukrah not found. Skipping...
# Processessing Record 32 of Set 6 | kaitangata
# Processessing Record 33 of Set 6 | quelimane
# Processessing Record 34 of Set 6 | pampa
# nizhneyansk not found. Skipping...
# Processessing Record 35 of Set 6 | caravelas
# Processessing Record 36 of Set 6 | balabac
# Processessing Record 37 of Set 6 | hoquiam
# Processessing Record 38 of Set 6 | buraydah
# Processessing Record 39 of Set 6 | port augusta
# Processessing Record 40 of Set 6 | gubkinskiy
# Processessing Record 41 of Set 6 | port-gentil
# sorvag not found. Skipping...
# Processessing Record 42 of Set 6 | maragogi
# Processessing Record 43 of Set 6 | borogontsy
# Processessing Record 44 of Set 6 | tazmalt
# Processessing Record 45 of Set 6 | soyo
# Processessing Record 46 of Set 6 | moron
# Processessing Record 47 of Set 6 | atasu
# sentyabrskiy not found. Skipping...
# Processessing Record 48 of Set 6 | sao joao da barra
# Processessing Record 49 of Set 6 | calabozo
# Processessing Record 50 of Set 6 | alice springs
# Processessing Record 1 of Set 7 | bethel
# Processessing Record 2 of Set 7 | putina
# Processessing Record 3 of Set 7 | grand gaube
# Processessing Record 4 of Set 7 | ajdabiya
# Processessing Record 5 of Set 7 | savonlinna
# qingan not found. Skipping...
# Processessing Record 6 of Set 7 | whitehorse
# Processessing Record 7 of Set 7 | inuvik
# Processessing Record 8 of Set 7 | veraval
# Processessing Record 9 of Set 7 | vila velha
# Processessing Record 10 of Set 7 | baculin
# Processessing Record 11 of Set 7 | naze
# Processessing Record 12 of Set 7 | kamenka
# Processessing Record 13 of Set 7 | san agustin
# Processessing Record 14 of Set 7 | yablonovo
# Processessing Record 15 of Set 7 | narsaq
# Processessing Record 16 of Set 7 | broken hill
# Processessing Record 17 of Set 7 | porto novo
# crab hill not found. Skipping...
# armacao dos buzios not found. Skipping...
# Processessing Record 18 of Set 7 | tessalit
# Processessing Record 19 of Set 7 | tamiahua
# Processessing Record 20 of Set 7 | dwarka
# Processessing Record 21 of Set 7 | edgecumbe
# Processessing Record 22 of Set 7 | namatanai
# Processessing Record 23 of Set 7 | niquelandia
# Processessing Record 24 of Set 7 | lazaro cardenas
# Processessing Record 25 of Set 7 | sabanagrande
# Processessing Record 26 of Set 7 | chegutu
# Processessing Record 27 of Set 7 | ballina
# Processessing Record 28 of Set 7 | buriti dos lopes
# Processessing Record 29 of Set 7 | spanish fork
# Processessing Record 30 of Set 7 | faaborg
# Processessing Record 31 of Set 7 | tiksi
# Processessing Record 32 of Set 7 | catarman
# Processessing Record 33 of Set 7 | la roda
# Processessing Record 34 of Set 7 | skjervoy
# Processessing Record 35 of Set 7 | redmond
# Processessing Record 36 of Set 7 | luderitz
# Processessing Record 37 of Set 7 | winchester
# umzimvubu not found. Skipping...
# Processessing Record 38 of Set 7 | kavaratti
# Processessing Record 39 of Set 7 | norwich
# Processessing Record 40 of Set 7 | phrae
# Processessing Record 41 of Set 7 | margate
# Processessing Record 42 of Set 7 | richards bay
# Processessing Record 43 of Set 7 | calama
# afmadu not found. Skipping...
# Processessing Record 44 of Set 7 | hamilton
# Processessing Record 45 of Set 7 | sigli
# Processessing Record 46 of Set 7 | jilemnice
# Processessing Record 47 of Set 7 | praia da vitoria
# Processessing Record 48 of Set 7 | santa vitoria
# Processessing Record 49 of Set 7 | bonavista
# Processessing Record 50 of Set 7 | ternovka
# tapaua not found. Skipping...
# Processessing Record 1 of Set 8 | louth
# Processessing Record 2 of Set 8 | mantsala
# Processessing Record 3 of Set 8 | cumana
# Processessing Record 4 of Set 8 | pontianak
# Processessing Record 5 of Set 8 | tuma

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": city_list,
    "Cloudiness": cloud,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lon,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
}

weather_df = pd.DataFrame(weather_dict)
weather_df.head()
weather_df.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(lat, max_temp, edgecolors='black', linewidths=.75)
plt.title("City Latitude vs. Max Temperature (9/3/2018)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(lat, humidity, edgecolors='black', linewidths=.75)
plt.title("City Latitude vs. Humidity (9/3/2018)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat, cloud, edgecolors='black', linewidths=.75)
plt.title("City Latitude vs. Cloudiness (9/3/2018)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat, wind_speed, edgecolors='black', linewidths=.75)
plt.title("City Latitude vs. Wind Speed (9/3/2018)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
