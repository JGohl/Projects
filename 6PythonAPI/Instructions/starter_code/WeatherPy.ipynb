# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
temp = []
wind_speed = []
cloud = []
country = []
date = []
humidity = []
lat = []
lon = []
max_temp = []
city_list = []

city_record_count = 0
city_count = 0
set_count = 1
print("Beginning Data Retrieval")
print('-------------------------------')

for city in cities:
    response = requests.get(query_url + city).json()
    try:
        city_record_count += 1
        city_list.append(response['name'])
        temp.append(response['main']['temp'])
        wind_speed.append(response['wind']['speed'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        print('Processessing Record ' + str(city_record_count) + " of Set " + str(set_count) + " | " + city)
        if city_record_count == 50:
            city_record_count = 0
            set_count += 1
            city_count += 1
    except KeyError:
        city_record_count -= 1
        print(city + ' not found. Skipping...')
    except ConnectionError:
        print("Connection Error")
        continue
    except ProtocalError:
        print("Protocal Error")
        continue
            
print('-------------------------------')
print('Data Retrieval Complete')
print('-------------------------------')
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processessing Record 1 of Set 1 | provideniya
# Processessing Record 2 of Set 1 | kenai
# Processessing Record 3 of Set 1 | sao filipe
# Processessing Record 4 of Set 1 | manturovo
# Processessing Record 5 of Set 1 | balabac
# Processessing Record 6 of Set 1 | tuktoyaktuk
# Processessing Record 7 of Set 1 | ostersund
# Processessing Record 8 of Set 1 | punta arenas
# Processessing Record 9 of Set 1 | bredasdorp
# Processessing Record 10 of Set 1 | kapaa
# Processessing Record 11 of Set 1 | churapcha
# Processessing Record 12 of Set 1 | bluff
# Processessing Record 13 of Set 1 | mataura
# Processessing Record 14 of Set 1 | ushuaia
# Processessing Record 15 of Set 1 | puerto ayora
# Processessing Record 16 of Set 1 | port elizabeth
# Processessing Record 17 of Set 1 | katsuura
# Processessing Record 18 of Set 1 | albany
# Processessing Record 19 of Set 1 | trieste
# Processessing Record 20 of Set 1 | pacific grove
# Processessing Record 21 of Set 1 | manokwari
# Processessing Record 22 of Set 1 | vestmannaeyjar
# Processessing Record 23 of Set 1 | qaanaaq
# Processessing Record 24 of Set 1 | luganville
# Processessing Record 25 of Set 1 | nantucket
# Processessing Record 26 of Set 1 | rikitea
# Processessing Record 27 of Set 1 | ibotirama
# Processessing Record 28 of Set 1 | yellowknife
# Processessing Record 29 of Set 1 | kampong cham
# Processessing Record 30 of Set 1 | virginia beach
# Processessing Record 31 of Set 1 | betlitsa
# Processessing Record 32 of Set 1 | san juan
# Processessing Record 33 of Set 1 | sao joao da barra
# Processessing Record 34 of Set 1 | canberra
# Processessing Record 35 of Set 1 | tilichiki
# Processessing Record 36 of Set 1 | pachino
# Processessing Record 37 of Set 1 | mecca
# Processessing Record 38 of Set 1 | atuona
# Processessing Record 39 of Set 1 | poum
# taolanaro not found. Skipping...
# Processessing Record 40 of Set 1 | hobyo
# Processessing Record 41 of Set 1 | port alfred
# Processessing Record 42 of Set 1 | komsomolskiy
# Processessing Record 43 of Set 1 | singaraja
# Processessing Record 44 of Set 1 | pevek
# Processessing Record 45 of Set 1 | kununurra
# Processessing Record 46 of Set 1 | lubao
# Processessing Record 47 of Set 1 | avarua
# Processessing Record 48 of Set 1 | plettenberg bay
# Processessing Record 49 of Set 1 | grootfontein
# Processessing Record 50 of Set 1 | cape town
# Processessing Record 1 of Set 2 | berlevag
# Processessing Record 2 of Set 2 | bambous virieux
# Processessing Record 3 of Set 2 | gat
# Processessing Record 4 of Set 2 | jardim
# Processessing Record 5 of Set 2 | havelock
# Processessing Record 6 of Set 2 | saskylakh
# Processessing Record 7 of Set 2 | tasiilaq
# illoqqortoormiut not found. Skipping...
# Processessing Record 8 of Set 2 | naze
# saint-fabien not found. Skipping...
# Processessing Record 9 of Set 2 | banda aceh
# Processessing Record 10 of Set 2 | lavumisa
# andenes not found. Skipping...
# Processessing Record 11 of Set 2 | nikolskoye
# Processessing Record 12 of Set 2 | carnarvon
# Processessing Record 13 of Set 2 | ponta delgada
# Processessing Record 14 of Set 2 | barrow
# Processessing Record 15 of Set 2 | jamestown
# Processessing Record 16 of Set 2 | hobart
# Processessing Record 17 of Set 2 | kaeo
# Processessing Record 18 of Set 2 | busselton
# tsihombe not found. Skipping...
# Processessing Record 19 of Set 2 | jonuta
# Processessing Record 20 of Set 2 | sakaiminato
# Processessing Record 21 of Set 2 | kaseda
# Processessing Record 22 of Set 2 | arraial do cabo
# Processessing Record 23 of Set 2 | baykit
# Processessing Record 24 of Set 2 | knysna
# Processessing Record 25 of Set 2 | merauke
# Processessing Record 26 of Set 2 | ayan
# Processessing Record 27 of Set 2 | burnie
# Processessing Record 28 of Set 2 | ilulissat
# lolua not found. Skipping...
# Processessing Record 29 of Set 2 | chuy
# Processessing Record 30 of Set 2 | mount gambier
# Processessing Record 31 of Set 2 | havoysund
# Processessing Record 32 of Set 2 | oranjemund
# Processessing Record 33 of Set 2 | new norfolk
# Processessing Record 34 of Set 2 | upernavik
# Processessing Record 35 of Set 2 | arica
# Processessing Record 36 of Set 2 | la rioja
# Processessing Record 37 of Set 2 | dikson
# barbar not found. Skipping...
# Processessing Record 38 of Set 2 | novi sanzhary
# Processessing Record 39 of Set 2 | parrita
# Processessing Record 40 of Set 2 | zhezkazgan
# Processessing Record 41 of Set 2 | comodoro rivadavia
# Processessing Record 42 of Set 2 | kavieng
# Processessing Record 43 of Set 2 | kruisfontein
# Processessing Record 44 of Set 2 | ahuimanu
# Processessing Record 45 of Set 2 | thinadhoo
# Processessing Record 46 of Set 2 | bereda
# Processessing Record 47 of Set 2 | san cristobal
# Processessing Record 48 of Set 2 | nanortalik
# nizhneyansk not found. Skipping...
# Processessing Record 49 of Set 2 | khatanga
# Processessing Record 50 of Set 2 | nakhon phanom
# mys shmidta not found. Skipping...
# Processessing Record 1 of Set 3 | fortuna
# Processessing Record 2 of Set 3 | pangnirtung
# Processessing Record 3 of Set 3 | ormara
# Processessing Record 4 of Set 3 | san francisco
# Processessing Record 5 of Set 3 | kamaishi
# Processessing Record 6 of Set 3 | ribeira grande
# Processessing Record 7 of Set 3 | tazovskiy
# Processessing Record 8 of Set 3 | palana
# Processessing Record 9 of Set 3 | goundam
# Processessing Record 10 of Set 3 | georgetown
# Processessing Record 11 of Set 3 | yeppoon
# Processessing Record 12 of Set 3 | vila velha
# Processessing Record 13 of Set 3 | hamilton
# Processessing Record 14 of Set 3 | matara
# Processessing Record 15 of Set 3 | hun
# barentsburg not found. Skipping...
# Processessing Record 16 of Set 3 | yumen
# Processessing Record 17 of Set 3 | epe
# Processessing Record 18 of Set 3 | zhigansk
# Processessing Record 19 of Set 3 | vaini
# Processessing Record 20 of Set 3 | alcala de henares
# Processessing Record 21 of Set 3 | miyako
# Processessing Record 22 of Set 3 | qaqortoq
# Processessing Record 23 of Set 3 | blagoveshchensk
# Processessing Record 24 of Set 3 | galle
# Processessing Record 25 of Set 3 | sao miguel
# Processessing Record 26 of Set 3 | chokurdakh
# Processessing Record 27 of Set 3 | keti bandar
# Processessing Record 28 of Set 3 | clyde river
# Processessing Record 29 of Set 3 | brae
# svetlyy not found. Skipping...
# Processessing Record 30 of Set 3 | karlshamn
# Processessing Record 31 of Set 3 | kieta
# Processessing Record 32 of Set 3 | shimoda
# Processessing Record 33 of Set 3 | torbay
# Processessing Record 34 of Set 3 | faanui
# Processessing Record 35 of Set 3 | coquimbo
# olafsvik not found. Skipping...
# Processessing Record 36 of Set 3 | bethel
# Processessing Record 37 of Set 3 | airai
# Processessing Record 38 of Set 3 | amarante do maranhao
# bengkulu not found. Skipping...
# Processessing Record 39 of Set 3 | laguna
# Processessing Record 40 of Set 3 | tremedal
# sentyabrskiy not found. Skipping...
# Processessing Record 41 of Set 3 | itoman
# Processessing Record 42 of Set 3 | esperance
# Processessing Record 43 of Set 3 | lebu
# samusu not found. Skipping...
# Processessing Record 44 of Set 3 | jumla
# Processessing Record 45 of Set 3 | coihaique
# Processessing Record 46 of Set 3 | nouakchott
# Processessing Record 47 of Set 3 | manta
# Processessing Record 48 of Set 3 | zeya
# Processessing Record 49 of Set 3 | kodiak
# Processessing Record 50 of Set 3 | lagoa
# Processessing Record 1 of Set 4 | hithadhoo
# Processessing Record 2 of Set 4 | demirci
# Processessing Record 3 of Set 4 | vilyuysk
# Processessing Record 4 of Set 4 | kalyazin
# Processessing Record 5 of Set 4 | at-bashi
# Processessing Record 6 of Set 4 | pestretsy
# tumannyy not found. Skipping...
# Processessing Record 7 of Set 4 | bathsheba
# Processessing Record 8 of Set 4 | ngunguru
# Processessing Record 9 of Set 4 | yulara
# Processessing Record 10 of Set 4 | summerland
# Processessing Record 11 of Set 4 | juneau
# Processessing Record 12 of Set 4 | hargeysa
# Processessing Record 13 of Set 4 | boddam
# Processessing Record 14 of Set 4 | jumilla
# Processessing Record 15 of Set 4 | east london
# Processessing Record 16 of Set 4 | puksoozero
# Processessing Record 17 of Set 4 | port hardy
# Processessing Record 18 of Set 4 | biak
# Processessing Record 19 of Set 4 | codrington
# Processessing Record 20 of Set 4 | cidreira
# Processessing Record 21 of Set 4 | seydi
# Processessing Record 22 of Set 4 | lompoc
# sorvag not found. Skipping...
# Processessing Record 23 of Set 4 | ballina
# Processessing Record 24 of Set 4 | ponta do sol
# Processessing Record 25 of Set 4 | tessalit
# Processessing Record 26 of Set 4 | saint george
# Processessing Record 27 of Set 4 | hilo
# Processessing Record 28 of Set 4 | christchurch
# saleaula not found. Skipping...
# Processessing Record 29 of Set 4 | port lincoln
# Processessing Record 30 of Set 4 | waingapu
# Processessing Record 31 of Set 4 | saint-pierre
# tuggurt not found. Skipping...
# Processessing Record 32 of Set 4 | saint-philippe
# Processessing Record 33 of Set 4 | rio gallegos
# Processessing Record 34 of Set 4 | tiksi
# Processessing Record 35 of Set 4 | hays
# Processessing Record 36 of Set 4 | mayumba
# sumbawa not found. Skipping...
# Processessing Record 37 of Set 4 | castro
# Processessing Record 38 of Set 4 | mount hagen
# Processessing Record 39 of Set 4 | mahebourg
# Processessing Record 40 of Set 4 | visby
# Processessing Record 41 of Set 4 | nizwa
# Processessing Record 42 of Set 4 | padilla
# Processessing Record 43 of Set 4 | didsbury
# Processessing Record 44 of Set 4 | amahai
# Processessing Record 45 of Set 4 | menongue
# Processessing Record 46 of Set 4 | broome
# Processessing Record 47 of Set 4 | salta
# Processessing Record 48 of Set 4 | shwebo
# Processessing Record 49 of Set 4 | butaritari
# Processessing Record 50 of Set 4 | hermanus
# Processessing Record 1 of Set 5 | muros
# yambio not found. Skipping...
# Processessing Record 2 of Set 5 | yar-sale
# Processessing Record 3 of Set 5 | necochea
# Processessing Record 4 of Set 5 | lerwick
# Processessing Record 5 of Set 5 | mazagao
# Processessing Record 6 of Set 5 | orastie
# yirol not found. Skipping...
# Processessing Record 7 of Set 5 | bairnsdale
# Processessing Record 8 of Set 5 | castro marim
# Processessing Record 9 of Set 5 | katobu
# Processessing Record 10 of Set 5 | trofors
# Processessing Record 11 of Set 5 | aksu
# belushya guba not found. Skipping...
# Processessing Record 12 of Set 5 | ziro
# Processessing Record 13 of Set 5 | touros
# Processessing Record 14 of Set 5 | thompson
# Processessing Record 15 of Set 5 | jinchang
# qui nhon not found. Skipping...
# Processessing Record 16 of Set 5 | yen bai
# Processessing Record 17 of Set 5 | kargasok
# Processessing Record 18 of Set 5 | waldheim
# Processessing Record 19 of Set 5 | nevelsk
# palabuhanratu not found. Skipping...
# Processessing Record 20 of Set 5 | kerema
# Processessing Record 21 of Set 5 | grindavik
# Processessing Record 22 of Set 5 | cheney
# Processessing Record 23 of Set 5 | hofn
# Processessing Record 24 of Set 5 | noshiro
# Processessing Record 25 of Set 5 | raudeberg
# Processessing Record 26 of Set 5 | vanimo
# Processessing Record 27 of Set 5 | edd
# Processessing Record 28 of Set 5 | itarema
# Processessing Record 29 of Set 5 | tecoanapa
# Processessing Record 30 of Set 5 | miandrivazo
# Processessing Record 31 of Set 5 | luangwa
# Processessing Record 32 of Set 5 | kaitangata
# Processessing Record 33 of Set 5 | kurilsk
# Processessing Record 34 of Set 5 | batamshinskiy
# Processessing Record 35 of Set 5 | newport
# Processessing Record 36 of Set 5 | cabedelo
# Processessing Record 37 of Set 5 | quesnel
# Processessing Record 38 of Set 5 | lincoln
# Processessing Record 39 of Set 5 | kovdor
# Processessing Record 40 of Set 5 | leningradskiy
# Processessing Record 41 of Set 5 | vardo
# Processessing Record 42 of Set 5 | victoria point
# Processessing Record 43 of Set 5 | chernyshevskiy
# Processessing Record 44 of Set 5 | shingu
# Processessing Record 45 of Set 5 | nouadhibou
# Processessing Record 46 of Set 5 | palmer
# Processessing Record 47 of Set 5 | kloulklubed
# attawapiskat not found. Skipping...
# Processessing Record 48 of Set 5 | tura
# Processessing Record 49 of Set 5 | sur
# Processessing Record 50 of Set 5 | bonavista
# Processessing Record 1 of Set 6 | makakilo city
# Processessing Record 2 of Set 6 | placer
# Processessing Record 3 of Set 6 | mar del plata
# Processessing Record 4 of Set 6 | beringovskiy
# Processessing Record 5 of Set 6 | rawson
# Processessing Record 6 of Set 6 | paka
# Processessing Record 7 of Set 6 | beloha
# Processessing Record 8 of Set 6 | kendari
# Processessing Record 9 of Set 6 | gorodishche
# Processessing Record 10 of Set 6 | geraldton
# Processessing Record 11 of Set 6 | alugan
# Processessing Record 12 of Set 6 | zhanaozen
# Processessing Record 13 of Set 6 | tarsus
# Processessing Record 14 of Set 6 | eenhana
# Processessing Record 15 of Set 6 | langsa
# Processessing Record 16 of Set 6 | pangkalanbuun
# Processessing Record 17 of Set 6 | los llanos de aridane
# Processessing Record 18 of Set 6 | sangar
# Processessing Record 19 of Set 6 | adamantina
# Processessing Record 20 of Set 6 | borogontsy
# Processessing Record 21 of Set 6 | santiago de cao
# Processessing Record 22 of Set 6 | tambovka
# Processessing Record 23 of Set 6 | yerbogachen
# Processessing Record 24 of Set 6 | victoria
# Processessing Record 25 of Set 6 | manuk mangkaw
# shirgaon not found. Skipping...
# andselv not found. Skipping...
# Processessing Record 26 of Set 6 | camacha
# Processessing Record 27 of Set 6 | boa vista
# Processessing Record 28 of Set 6 | lazarev
# mazulskiy not found. Skipping...
# Processessing Record 29 of Set 6 | avera
# Processessing Record 30 of Set 6 | amga
# Processessing Record 31 of Set 6 | khalkhal
# Processessing Record 32 of Set 6 | ruidoso
# Processessing Record 33 of Set 6 | margate
# Processessing Record 34 of Set 6 | sao joaquim
# Processessing Record 35 of Set 6 | faenza
# Processessing Record 36 of Set 6 | soyaux
# Processessing Record 37 of Set 6 | kamina
# Processessing Record 38 of Set 6 | sanmenxia
# Processessing Record 39 of Set 6 | abu samrah
# Processessing Record 40 of Set 6 | mayor pablo lagerenza
# Processessing Record 41 of Set 6 | luderitz
# Processessing Record 42 of Set 6 | sovetskaya gavan
# Processessing Record 43 of Set 6 | kichmengskiy gorodok
# Processessing Record 44 of Set 6 | north las vegas
# amancio not found. Skipping...
# Processessing Record 45 of Set 6 | ancud
# Processessing Record 46 of Set 6 | matagami
# Processessing Record 47 of Set 6 | alekseyevsk
# Processessing Record 48 of Set 6 | saint anthony
# Processessing Record 49 of Set 6 | pisco
# Processessing Record 50 of Set 6 | bilibino
# Processessing Record 1 of Set 7 | saldanha
# Processessing Record 2 of Set 7 | casma
# Processessing Record 3 of Set 7 | eresos
# Processessing Record 4 of Set 7 | lavrentiya
# Processessing Record 5 of Set 7 | balkhash
# Processessing Record 6 of Set 7 | quelimane
# Processessing Record 7 of Set 7 | chapais
# Processessing Record 8 of Set 7 | udachnyy
# Processessing Record 9 of Set 7 | olinda
# Processessing Record 10 of Set 7 | kushima
# sataua not found. Skipping...
# vaitupu not found. Skipping...
# Processessing Record 11 of Set 7 | alofi
# Processessing Record 12 of Set 7 | peniche
# Processessing Record 13 of Set 7 | salumbar
# Processessing Record 14 of Set 7 | varangaon
# Processessing Record 15 of Set 7 | bhadrachalam
# Processessing Record 16 of Set 7 | shahr-e kord
# Processessing Record 17 of Set 7 | varfurile
# Processessing Record 18 of Set 7 | prince rupert
# Processessing Record 19 of Set 7 | pangai
# Processessing Record 20 of Set 7 | vega de alatorre
# Processessing Record 21 of Set 7 | batagay
# Processessing Record 22 of Set 7 | lubango
# Processessing Record 23 of Set 7 | san miguel
# Processessing Record 24 of Set 7 | longyearbyen
# Processessing Record 25 of Set 7 | taoudenni
# Processessing Record 26 of Set 7 | methoni
# Processessing Record 27 of Set 7 | kyren
# Processessing Record 28 of Set 7 | noumea
# Processessing Record 29 of Set 7 | asadabad
# Processessing Record 30 of Set 7 | solnechnyy
# Processessing Record 31 of Set 7 | praya
# Processessing Record 32 of Set 7 | popondetta
# Processessing Record 33 of Set 7 | nahrin
# Processessing Record 34 of Set 7 | iroquois falls
# Processessing Record 35 of Set 7 | hasaki
# Processessing Record 36 of Set 7 | san patricio
# Processessing Record 37 of Set 7 | kibala
# Processessing Record 38 of Set 7 | alakurtti
# Processessing Record 39 of Set 7 | guerrero negro
# Processessing Record 40 of Set 7 | cherskiy
# Processessing Record 41 of Set 7 | rundu
# Processessing Record 42 of Set 7 | kudahuvadhoo
# Processessing Record 43 of Set 7 | walla walla
# Processessing Record 44 of Set 7 | manjacaze
# Processessing Record 45 of Set 7 | tezu
# Processessing Record 46 of Set 7 | lata
# Processessing Record 47 of Set 7 | riyadh
# Processessing Record 48 of Set 7 | kroya
# Processessing Record 49 of Set 7 | ranot
# bolungarvik not found. Skipping...
# louisbourg not found. Skipping...
# aflu not found. Skipping...
# Processessing Record 50 of Set 7 | cabo san lucas
# Processessing Record 1 of Set 8 | salalah
# Processessing Record 2 of Set 8 | chiredzi
# Processessing Record 3 of Set 8 | rocha
# Processessing Record 4 of Set 8 | olga
# Processessing Record 5 of Set 8 | nara
# Processessing Record 6 of Set 8 | sorland
# Processessing Record 7 of Set 8 | santa lucia
# tabiauea not found. Skipping...
# Processessing Record 8 of Set 8 | piacabucu
# Processessing Record 9 of Set 8 | byron bay
# Processessing Record 10 of Set 8 | norman wells
# Processessing Record 11 of Set 8 | goure
# Processessing Record 12 of Set 8 | cayenne
# tasbuget not found. Skipping...
# Processessing Record 13 of Set 8 | severo-kurilsk
# Processessing Record 14 of Set 8 | kampot
# Processessing Record 15 of Set 8 | charlottesville
# Processessing Record 16 of Set 8 | harper
# Processessing Record 17 of Set 8 | lasa
# Processessing Record 18 of Set 8 | narsaq
# Processessing Record 19 of Set 8 | manavalakurichi
# fort saint john not found. Skipping...
# samalaeulu not found. Skipping...
# Processessing Record 20 of Set 8 | sazonovo
# Processessing Record 21 of Set 8 | kushiro
# Processessing Record 22 of Set 8 | belyy yar
# Processessing Record 23 of Set 8 | cooma
# Processessing Record 24 of Set 8 | jieshi
# Processessing Record 25 of Set 8 | sibu
# Processessing Record 26 of Set 8 | sillanwali
# Processessing Record 27 of Set 8 | gamba
# Processessing Record 28 of Set 8 | mayo
# Processessing Record 29 of Set 8 | vao
# Processessing Record 30 of Set 8 | hambantota
# marv dasht not found. Skipping...
# koungou not found. Skipping...
# umzimvubu not found. Skipping...
# Processessing Record 31 of Set 8 | alyangula
# krasnoselkup not found. Skipping...
# Processessing Record 32 of Set 8 | sisimiut
# Processessing Record 33 of Set 8 | flinders
# Processessing Record 34 of Set 8 | alta floresta
# Processessing Record 35 of Set 8 | ankazoabo
# Processessing Record 36 of Set 8 | jizan
# Processessing Record 37 of Set 8 | nevesinje
# Processessing Record 38 of Set 8 | antofagasta
# Processessing Record 39 of Set 8 | daru
# Processessing Record 40 of Set 8 | bendigo
# Processessing Record 41 of Set 8 | mount isa
# Processessing Record 42 of Set 8 | nacala
# Processessing Record 43 of Set 8 | angoche
# Processessing Record 44 of Set 8 | klaksvik
# waling not found. Skipping...
# gangotri not found. Skipping...
# Processessing Record 45 of Set 8 | katherine
# Processessing Record 46 of Set 8 | mogadishu
# Processessing Record 47 of Set 8 | anapskaya
# Processessing Record 48 of Set 8 | loanda
# Processessing Record 49 of Set 8 | leshukonskoye
# Processessing Record 50 of Set 8 | canguaretama
# Processessing Record 1 of Set 9 | ossora
# Processessing Record 2 of Set 9 | talnakh
# Processessing Record 3 of Set 9 | kutum
# Processessing Record 4 of Set 9 | lamu
# toliary not found. Skipping...
# Processessing Record 5 of Set 9 | la rochelle
# Processessing Record 6 of Set 9 | san quintin
# Processessing Record 7 of Set 9 | sibolga
# Processessing Record 8 of Set 9 | chippewa falls
# Processessing Record 9 of Set 9 | port blair
# dianopolis not found. Skipping...
# Processessing Record 10 of Set 9 | olds
# Processessing Record 11 of Set 9 | tuatapere
# Processessing Record 12 of Set 9 | denpasar
# Processessing Record 13 of Set 9 | garowe
# Processessing Record 14 of Set 9 | loiza
# Processessing Record 15 of Set 9 | samarai
# Processessing Record 16 of Set 9 | mirabad
# Processessing Record 17 of Set 9 | sovetskiy
# Processessing Record 18 of Set 9 | thayetmyo
# Processessing Record 19 of Set 9 | honggang
# Processessing Record 20 of Set 9 | erzin
# Processessing Record 21 of Set 9 | palmerston
# halalo not found. Skipping...
# Processessing Record 22 of Set 9 | flin flon
# Processessing Record 23 of Set 9 | wuwei
# Processessing Record 24 of Set 9 | champerico
# Processessing Record 25 of Set 9 | half moon bay
# Processessing Record 26 of Set 9 | inirida
# Processessing Record 27 of Set 9 | norden
# Processessing Record 28 of Set 9 | tateyama
# Processessing Record 29 of Set 9 | abeche
# Processessing Record 30 of Set 9 | wamba
# afmadu not found. Skipping...
# Processessing Record 31 of Set 9 | ketchikan
# Processessing Record 32 of Set 9 | kavaratti
# Processessing Record 33 of Set 9 | mabaruma
# Processessing Record 34 of Set 9 | smithers
# Processessing Record 35 of Set 9 | kempsey
# Processessing Record 36 of Set 9 | constitucion
# Processessing Record 37 of Set 9 | sabak
# Processessing Record 38 of Set 9 | roald
# Processessing Record 39 of Set 9 | barreiras
# Processessing Record 40 of Set 9 | haines junction
# Processessing Record 41 of Set 9 | whitehorse
# Processessing Record 42 of Set 9 | mokhsogollokh
# Processessing Record 43 of Set 9 | bauchi
# Processessing Record 44 of Set 9 | aklavik
# Processessing Record 45 of Set 9 | katangli
# Processessing Record 46 of Set 9 | ixtapa
# Processessing Record 47 of Set 9 | saint-augustin
# Processessing Record 48 of Set 9 | pontes e lacerda
# Processessing Record 49 of Set 9 | kinablangan
# Processessing Record 50 of Set 9 | fort nelson
# burica not found. Skipping...
# Processessing Record 1 of Set 10 | tautira
# Processessing Record 2 of Set 10 | halifax
# himora not found. Skipping...
# Processessing Record 3 of Set 10 | dingle
# Processessing Record 4 of Set 10 | capoterra
# Processessing Record 5 of Set 10 | pilani
# Processessing Record 6 of Set 10 | mocuba
# Processessing Record 7 of Set 10 | sawakin
# Processessing Record 8 of Set 10 | adrar
# Processessing Record 9 of Set 10 | tarauaca
# Processessing Record 10 of Set 10 | penzance
# Processessing Record 11 of Set 10 | atambua
# Processessing Record 12 of Set 10 | san juan de colon
# Processessing Record 13 of Set 10 | mastung
# Processessing Record 14 of Set 10 | outlook
# Processessing Record 15 of Set 10 | urucui
# Processessing Record 16 of Set 10 | tabou
# Processessing Record 17 of Set 10 | santa maria
# Processessing Record 18 of Set 10 | yenagoa
# malwan not found. Skipping...
# Processessing Record 19 of Set 10 | eureka
# afgoye not found. Skipping...
# Processessing Record 20 of Set 10 | sokoni
# Processessing Record 21 of Set 10 | kahului
# Processessing Record 22 of Set 10 | san rafael
# Processessing Record 23 of Set 10 | kaitong
# Processessing Record 24 of Set 10 | rio grande
# Processessing Record 25 of Set 10 | shetpe
# Processessing Record 26 of Set 10 | sola
# Processessing Record 27 of Set 10 | ulyanovsk
# Processessing Record 28 of Set 10 | kirakira
# kachikau not found. Skipping...
# Processessing Record 29 of Set 10 | ostrovnoy
# Processessing Record 30 of Set 10 | vestmanna
# Processessing Record 31 of Set 10 | nzega
# Processessing Record 32 of Set 10 | sitka
# Processessing Record 33 of Set 10 | aginskoye
# Processessing Record 34 of Set 10 | namatanai
# mentok not found. Skipping...
# Processessing Record 35 of Set 10 | namibe
# Processessing Record 36 of Set 10 | dunedin
# Processessing Record 37 of Set 10 | hammond
# Processessing Record 38 of Set 10 | rio branco
# tayibe not found. Skipping...
# Processessing Record 39 of Set 10 | hereford
# Processessing Record 40 of Set 10 | galesong
# Processessing Record 41 of Set 10 | aswan
# ipora not found. Skipping...
# Processessing Record 42 of Set 10 | maniitsoq
# Processessing Record 43 of Set 10 | naberera
# Processessing Record 44 of Set 10 | westport
# Processessing Record 45 of Set 10 | puri
# Processessing Record 46 of Set 10 | braintree
# Processessing Record 47 of Set 10 | vila franca do campo
# Processessing Record 48 of Set 10 | san jeronimo
# Processessing Record 49 of Set 10 | sistranda
# korla not found. Skipping...
# Processessing Record 50 of Set 10 | coahuayana
# Processessing Record 1 of Set 11 | bitung
# Processessing Record 2 of Set 11 | klungkung
# Processessing Record 3 of Set 11 | aripuana
# haibowan not found. Skipping...
# Processessing Record 4 of Set 11 | san ramon
# Processessing Record 5 of Set 11 | sungaipenuh
# Processessing Record 6 of Set 11 | shaoyang
# Processessing Record 7 of Set 11 | muyezerskiy
# Processessing Record 8 of Set 11 | buraydah
# Processessing Record 9 of Set 11 | souillac
# Processessing Record 10 of Set 11 | hukuntsi
# bajo baudo not found. Skipping...
# asau not found. Skipping...
# Processessing Record 11 of Set 11 | busembatia
# Processessing Record 12 of Set 11 | namioka
# jibuti not found. Skipping...
# Processessing Record 13 of Set 11 | feldbach
# Processessing Record 14 of Set 11 | sekoma
# Processessing Record 15 of Set 11 | zemetchino
# Processessing Record 16 of Set 11 | sobolevo
# ye not found. Skipping...
# Processessing Record 17 of Set 11 | jiamusi
# Processessing Record 18 of Set 11 | padang
# Processessing Record 19 of Set 11 | eskisehir
# Processessing Record 20 of Set 11 | nemuro
# Processessing Record 21 of Set 11 | pyu
# catamarca not found. Skipping...
# Processessing Record 22 of Set 11 | alice springs
# Processessing Record 23 of Set 11 | caravelas
# Processessing Record 24 of Set 11 | kidal
# Processessing Record 25 of Set 11 | lyubar
# Processessing Record 26 of Set 11 | morgaushi
# Processessing Record 27 of Set 11 | antalaha
# Processessing Record 28 of Set 11 | spokane
# Processessing Record 29 of Set 11 | okha
# Processessing Record 30 of Set 11 | surt
# Processessing Record 31 of Set 11 | copacabana
# Processessing Record 32 of Set 11 | baripada
# gurgan not found. Skipping...
# Processessing Record 33 of Set 11 | looc
# mogochin not found. Skipping...
# Processessing Record 34 of Set 11 | shangrao
# Processessing Record 35 of Set 11 | alberton
# Processessing Record 36 of Set 11 | lilongwe
# Processessing Record 37 of Set 11 | richards bay
# Processessing Record 38 of Set 11 | payo
# Processessing Record 39 of Set 11 | dunn
# Processessing Record 40 of Set 11 | bathurst
# Processessing Record 41 of Set 11 | kiama
# Processessing Record 42 of Set 11 | severnyy-kospashskiy
# Processessing Record 43 of Set 11 | myingyan
# Processessing Record 44 of Set 11 | manacapuru
# Processessing Record 45 of Set 11 | shipunovo
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": city_list,
    "Cloudiness": cloud,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lon,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
}

weather_df = pd.DataFrame(weather_dict)
weather_df.head()
weather_df.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(lat, max_temp, edgecolors='black', linewidths=.75)
plt.title("City Latitude vs. Max Temperature (9/3/2018)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(lat, humidity, edgecolors='black', linewidths=.75)
plt.title("City Latitude vs. Humidity (9/3/2018)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat, cloud, edgecolors='black', linewidths=.75)
plt.title("City Latitude vs. Cloudiness (9/3/2018)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat, wind_speed, edgecolors='black', linewidths=.75)
plt.title("City Latitude vs. Wind Speed (9/3/2018)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
