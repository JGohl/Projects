# %%
# Create code to answer each of the following questions.
# Hint: You will need multiple target URLs and multiple API requests.

# Dependencies
import requests
import json
from pprint import pprint

# Retrieve Google API key from config.py
from config import gkey

# %%
# 1. What are the geocoordinates (latitude/longitude) of Seattle, Washington?
# Run a request to endpoint and convert result to json
# Target city
target_city = "Seattle, Washington"

# Build the endpoint URL
target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_city, gkey)

geo_data = requests.get(target_url).json()

# Print the json
# pprint(geo_data)

# Extract latitude and longitude
lat_seattle = geo_data["results"][0]["geometry"]["location"]["lat"]
lng_seattle = geo_data["results"][0]["geometry"]["location"]["lng"]

# Print the latitude and longitude
print('''
    City: {0}
    Latitude: {1}
    Longitude: {2}
    '''.format(target_city, lat_seattle, lng_seattle))
# Out:
#     City: Seattle, Washington
#     Latitude: 47.6062095
#     Longitude: -122.3320708

# %%
# 2. What are the geocoordinates (latitude/longitude) of The White House?

# Target city
target_city = "White House"

# Build the endpoint URL
target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_city, gkey)

geo_data = requests.get(target_url).json()

# Print the json
# pprint(geo_data)

# Extract latitude and longitude
lat_wh = geo_data["results"][0]["geometry"]["location"]["lat"]
lng_wh = geo_data["results"][0]["geometry"]["location"]["lng"]

# Print the latitude and longitude
print('''
    City: {0}
    Latitude: {1}
    Longitude: {2}
    '''.format(target_city, lat_wh, lng_wh))
# Out:
#     City: White House
#     Latitude: 38.8976763
#     Longitude: -77.0365298

# %%
# 3. Find the name andaddress of a bike store in Seattle, Washington.
#    Hint: See https://developers.google.com/places/web-service/supported_types

# geocoordinates
target_coordinates_seattle = "47.6062095, -122.3320708"
target_search_seattle = "bike shops"
target_radius_seattle = 80000
target_type_seattle = "bicycle_store"

# set up a parameters dictionary
params = {
    "location": target_coordinates_seattle,
    "keyword": target_search_seattle,
    "radius": target_radius_seattle,
    "type": target_type_seattle,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)
places_data = response.json()

#pprint(places_data)
print(places_data["results"][1]["name"])
print(places_data["results"][1]["vicinity"])
# Out:
# Performance Bicycle
# 4501 Roosevelt Way NE, Seattle

# %%
# 4. Find a balloon store near the White House.


# geocoordinates
target_coordinates_seattle = "38.8976763, -77.0365298"
target_search_seattle = "balloon"
target_radius_seattle = 80000
target_type_seattle = "store"

# set up a parameters dictionary
params = {
    "location": target_coordinates_seattle,
    "keyword": target_search_seattle,
    "radius": target_radius_seattle,
    "type": target_type_seattle,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)
places_data = response.json()

#pprint(places_data)
print(places_data["results"][0]["name"])
print(places_data["results"][0]["vicinity"])
# Out:
# Party Mania
# 8353 Leesburg Pike, Vienna

# %%
# 5. Find the nearest dentist to your house.
#    Hint: Use Google Maps to find your latitude and Google Places to find the
#    dentist. You will also need the rankby property.


# Target city
address = "1372 Bunts Rd., Lakewood, Ohio"

# Build the endpoint URL
target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(address, gkey)

geo_data = requests.get(target_url).json()

# Print the json
# pprint(geo_data)

# Extract latitude and longitude
lat_seattle = geo_data["results"][0]["geometry"]["location"]["lat"]
lng_seattle = geo_data["results"][0]["geometry"]["location"]["lng"]

# Print the latitude and longitude
print('''
    Address: {0}
    Latitude: {1}
    Longitude: {2}
    '''.format(address, lat_seattle, lng_seattle))
# Out:
#     Address: 1372 Bunts Rd., Lakewood, Ohio
#     Latitude: 41.4863393
#     Longitude: -81.7896921

# %%
# geocoordinates
target_coordinates = "41.4863393, -81.7896921"
target_search = "dentist"
target_radius = 8000
target_type = "dentist"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)
place_data = response.json()
pprint(place_data)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CrQCKQEAAIK0hUbCcokDnC76-kNVNVX23tEFw5Y6rm6hR8YxksuxqmltpoESv-jgFR4wdR8c6KtYy_a2GQv0JLNucXohatooeHkR4JZWFP-v1IL8vrb8whXRq0Oq3adjAW15-JyNdMa7jKGCASVAiZ4MRRvb546Gttu_4zBk7oCBm_rKgJRVSNG8mZ-2OL1wpSvrPcU49Gx0MHVPIIMui2l5lzB-Vp6FwwOcKZ3ijNZMlBLNWGzBYQBvsvhYQBEkmZaXQgDsd0ruazUgLa5J21p1uQaYBN72UuBSq8FtG4Rd5KpSWu2pQIluZn_dlucQrUF4QIycPOTg0oDiagNXi73zY1pTXN1fd_R06B8Da-kZVgNGuTXE8ERl2NZaRsAfH8l2OYPTVr9wL297G76fi_ODvWKE1cUSEOOF1UC7TF5gFeeQmjWNcVUaFOXk6HJ8CfBFJAPHeNKoM1oAIbMi',
Cleveland'},
#              {'geometry': {'location': {'lat': 41.4871005, 'lng': -81.707453},
#                            'viewport': {'northeast': {'lat': 41.48829457989272,
#                                                       'lng': -81.70593907010728},
#                                         'southwest': {'lat': 41.48559492010727,
#                                                       'lng': -81.70863872989273}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': '324f67410444bb9d759a2166a49567b94932f598',
#               'name': 'Hudec Dental',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1152,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115681353454866302021/photos">Hudec '
#                                                 'Dental</a>'],
#                           'photo_reference': 'CmRaAAAAjY9R8eicJFGfhz5Bk6tWD5kfGKwdTnGbep5HH7l-gfoQG16jtMLC_cTeXR1ClS9iA4g6DACOJa0NPWzHxwHHuq-f90Pau_xRI0UBlmfwRHwSxexVbKMEKDpn15v20simEhCKScfY0NJaNZxPNn0OWsdlGhSfwfMNOQkNOzoO1tYFV72q0NszTg',
#                           'width': 1153}],
#               'place_id': 'ChIJRd4_lG7wMIgRSWxOKwhjQYY',
#               'plus_code': {'compound_code': 'F7PV+R2 Cleveland, Ohio',
#                             'global_code': '86HWF7PV+R2'},
#               'rating': 4,
#               'reference': 'CmRbAAAA4kJiRD-JP7DdkxPAXxaduzfDUHuhsQKuXYkYtlVzJZr9afYOb3_WBNGyDxm254LcxKDsvUn0mZyuvsyR1HG4nysHlltpGoa-APTyUN4w_bV7cNh9_Db9CY0Zluh5fphwEhBgfgzvng-gjlUZwly8phhoGhQ3LszXrR0bOcQGPjVbvdfsVfAUTQ',
#               'scope': 'GOOGLE',
#               'types': ['dentist',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '1730 W 25th St, Cleveland'},
#              {'geometry': {'location': {'lat': 41.4620067,
#                                         'lng': -81.69753519999999},
#                            'viewport': {'northeast': {'lat': 41.46343147989271,
#                                                       'lng': -81.69616992010727},
#                                         'southwest': {'lat': 41.46073182010727,
#                                                       'lng': -81.69886957989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': 'b6dafca92bb40510f99eba01d776c04b364de971',
#               'name': 'Willen David M DDS',
#               'place_id': 'ChIJM7MZGQLwMIgR2-4_LL1nRVU',
#               'plus_code': {'compound_code': 'F862+RX Cleveland, Ohio',
#                             'global_code': '86HWF862+RX'},
#               'rating': 0,
#               'reference': 'CmRbAAAAyr3m2aY9-1w6puyOqDyHaFMrdFdilD6_tSUDaiaQloDDEI4whALOs5pBN71mUycCmY6QdJjZHUUbsc2RFE3HUHxhAPxIhDdmR5w9FYJxGCTGWmB9ItFMgrqN5epljqGIEhDtI8m7WIkav5HxvOV1V21rGhTTWAG0cNWgieEVC57zZz4XNoamtA',
#               'scope': 'GOOGLE',
#               'types': ['dentist',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '2500 Metrohealth Dr, Cleveland'},
#              {'geometry': {'location': {'lat': 41.4488197, 'lng': -81.8155551},
#                            'viewport': {'northeast': {'lat': 41.45034767989272,
#                                                       'lng': -81.81420222010729},
#                                         'southwest': {'lat': 41.44764802010728,
#                                                       'lng': -81.81690187989273}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': '7a5ff6439c6bf5d7973fb71f864a58852efa4dbe',
#               'name': 'West Park Dental',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1365,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113864272355614850592/photos">West '
#                                                 'Park Dental</a>'],
#                           'photo_reference': 'CmRaAAAA2diIqYwvhZqNGkyjSxmbR16k4evLIMNgYKFaoSTJLD8OMv8TJzGlhrzWH1UYHZ1qicSLZyLh5IGZMQl-u7ih1FNMEiDdUFiRZ_8VL5lS8bcRMGpUw3w4SUoZge2v7t6VEhCCHpgD7TWq-k-MyXjheZImGhSFJYGbhRMLDfHxIZ1tf-_DGC0VDg',
#                           'width': 2048}],
#               'place_id': 'ChIJndFzc6LtMIgRoTO3GhFPCyw',
#               'plus_code': {'compound_code': 'C5XM+GQ Cleveland, Ohio',
#                             'global_code': '86HWC5XM+GQ'},
#               'rating': 4.9,
#               'reference': 'CmRbAAAAo8xZtlsQLMLcAIQQH62CtMWWL9KMW8hhMwIVuhraSHbqAi34uTZsKlANHN3zNQdcRcdxs0kAWwvHNFhQCd0ij6OheHlCdSakUJBVbPc8eJ6Grv9xBLKaCsIl68IHC4ABEhBO7GhRiaFqYfkPTYuTybxqGhQi9387jBMCW51y3ddS0yJDidTqhg',
#               'scope': 'GOOGLE',
#               'types': ['dentist',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity':

#               'scope': 'GOOGLE',
#               'types': ['dentist',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '4163 Pearl Rd, Cleveland'},
#              {'geometry': {'location': {'lat': 41.4488091, 'lng': -81.8155395},
#                            'viewport': {'northeast': {'lat': 41.45034232989272,
#                                                       'lng': -81.81418652010727},
#                                         'southwest': {'lat': 41.44764267010727,
#                                                       'lng': -81.8168861798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': 'a0f39082fd86e231c164238466338335ee3321f2',
#               'name': 'Westpark Dental Associates: Michael E. Gallagher, '
#                       'D.D.S.',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 480,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108766386412968134261/photos">West '
#                                                 'Park Dental: Gallagher '
#                                                 'Michael E DDS</a>'],
#                           'photo_reference': 'CmRaAAAAvcm07pKlzk6uip0b0KPB9aVt5lCkBEwZNHy5TFa6VKi2lO0uj7dfgi6QdwTuVhWEZWXPZEPhzgTrkWi0Wh64h1JHcaQ5_IZuHeK8ZTaX-ngD11O8eCHSILNIT6tpbpeHEhCpb4CpChZySYzOSBKF_pM3GhTPJRz_I9ieerzFWobkx33kcadxPA',
#                           'width': 640}],
#               'place_id': 'ChIJndFzc6LtMIgRX8npAbU9lzc',
#               'plus_code': {'compound_code': 'C5XM+GQ Cleveland, Ohio',
#                             'global_code': '86HWC5XM+GQ'},
#               'rating': 0,
#               'reference': 'CmRbAAAAZf4h7X144l5M2ZBy9k_kLal7SHkHwsS09Mbdu666HaeYssE-CCEd4wkQyP6j-38-BufxlrP3TryKJ_KnP3uiLX0EkWT3Wr-4TQPa9CcVs3lc4mTxbKCjq3lJIADKcDnhEhBCh9i4bYOTUFfsPj21hEXjGhQPT0gRTL-wt_4mifiD6i_8Td06_w',
#               'scope': 'GOOGLE',
#               'types': ['dentist',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '17001 Albers Ave, Cleveland'},
#              {'geometry': {'location': {'lat': 41.4587896, 'lng': -81.8617884},
#                            'viewport': {'northeast': {'lat': 41.46013792989272,
#                                                       'lng': -81.86032757010727},
#                                         'southwest': {'lat': 41.45743827010728,
#                                                       'lng': -81.86302722989271}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': '548b70636858018e51bf4a681f2df51ff64cdc54',
#               'name': 'Richard E Betor Inc',
#               'opening_hours': {'open_now': False},
#               'place_id': 'ChIJbXh9EUztMIgRpBd-w-82QJU',
#               'plus_code': {'compound_code': 'F45Q+G7 Rocky River, Ohio',
#                             'global_code': '86HWF45Q+G7'},
#               'rating': 4.9,
#               'reference': 'CmRbAAAAT76oi_wZDl1ZAHE9nknAP-Io7T74NyjzXzyKqsN01MwZhFq74p8uudfWd6gydMAY_efTT86Yprs_EG1NFzn3xDYlNHmZCTXWuPSqif9W2uLqvRxinMGMvJ5LZEfWD3bDEhDrzmbm9_FnLiFWjyUcTVRyGhQFDxkd9l10gdy6wEMBSXKcpt3J1w',
#               'scope': 'GOOGLE',
#               'types': ['dentist',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '21851 Center Ridge Rd # 307, Cleveland'},
#              {'geometry': {'location': {'lat': 41.4851342, 'lng': -81.8196677},
#                            'viewport': {'northeast': {'lat': 41.48632132989272,
#                                                       'lng': -81.81826037010728},
#                                         'southwest': {'lat': 41.48362167010728,
#                                                       'lng': -81.82096002989273}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': '171583383b18e53662701d2bb59a84a03a7500fd',
#               'name': 'Linda Hippler DDS INC',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1536,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101838983152209122963/photos">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAAi3ewDJy8HwONOc2ihmEZZ8AILscFwnom2-Z85eW_mWly9X8SjapWPchGHNjEemx0D3nMYzuquCfZFSK1Ms64Lh4dMQgt0-Mta3bZF0tNKsLTQmY_wL2xB5jyvjNTYE1KEhDQMc1iLNj4oydUoOC26vTjGhSFWD-IeSwAzDrF8Q7qFCnVuCVxNA',
#                           'width': 2048}],
#               'place_id': 'ChIJ-5lxeGHyMIgRGJG8Fqb3dW4',
#               'plus_code': {'compound_code': 'F5PJ+34 Lakewood, Ohio',
#                             'global_code': '86HWF5PJ+34'},
#               'rating': 5,
#               'reference': 'CmRbAAAA3elr2FdQt2INx39_4zKtknPqe4xGQqFOFVJaUx7_Wi7ij_-iuaXM3ToKX-ReDBp0bL33cD_QgQhbLSKbxebCdnPPbs5o-BohL1851_srsMgqXbr6acmYPV3tVlwQBbOrEhC2ZLgAq7vVOsX-g-_m37PNGhQuIi0VJcBSg5jFqdprBWfb59N87w',
#               'scope': 'GOOGLE',
#               'types': ['dentist',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '17750 Detroit Ave, Lakewood'},
#              {'geometry': {'location': {'lat': 41.458594, 'lng': -81.861704},
#                            'viewport': {'northeast': {'lat': 41.45989637989272,
#                                                       'lng': -81.86035557010727},
#                                         'southwest': {'lat': 41.45719672010728,
#                                                       'lng': -81.86305522989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': '7bfac5a2bdf8803db0ae7a8f967a512f564abb29',
#               'name': 'Linda Rak Canepa DDS',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 417,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103198482003995763473/photos">Linda '
#                                                 'Rak Canepa DDS</a>'],
#                           'photo_reference': 'CmRaAAAAQojPusuul1Bi2mxtqOm2j5kSAKqu20QUHgxiPg8PIc3jvZaHgyInQAmcqkaqlMMaJJFAomVKG2L5KO7U_cE-prKAHaAAFG0wrSYkOokkWq_tfhLZrgffkHiEIawuvGrhEhA1iRk7zCG2ciAigL9CZh72GhTmLZyfr50hkhUGiuBiXHimtjkEEQ',
#                           'width': 625}],
#               'place_id': 'ChIJbXh9EUztMIgR9OvPoAatykw',
#               'plus_code': {'compound_code': 'F45Q+C8 Rocky River, Ohio',
#                             'global_code': '86HWF45Q+C8'},
#               'rating': 5,
#               'reference': 'CmRbAAAAY-JlxxDPLz3SJH9Mc8bhdD9Vd52I4Clty7UiKVvYq-wwEWp-V68LqXPXXXLlbh08xgnGPms_W76x566l0wuIK_dOpmx02rmih6NxYEoYrca8bMqhjZjZI-oc9-ssOMZbEhAbS-21GPtqJkudpvfUOohyGhT9YM4sFHdrfZCyQcdTS1OmXlOP0w',
#               'scope': 'GOOGLE',
#               'types': ['dentist',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '21851 Center Ridge Rd #308, Rocky River'},
#              {'geometry': {'location': {'lat': 41.4486927, 'lng': -81.8455776},
#                            'viewport': {'northeast': {'lat': 41.44994052989271,
#                                                       'lng': -81.84417962010728},
#                                         'southwest': {'lat': 41.44724087010727,
#                                                       'lng': -81.84687927989273}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': '0bb0dd91f9764aa7205e810d30eeea171eecef01',
#               'name': 'Thomas Touhey D.D.S.',
#               'opening_hours': {'open_now': False},
#               'place_id': 'ChIJ4fAVNj7tMIgREBGjaCx9skw',
#               'plus_code': {'compound_code': 'C5X3+FQ Fairview Park, Ohio',
#                             'global_code': '86HWC5X3+FQ'},
#               'rating': 5,
#               'reference': 'CmRbAAAAwEr2WoO_DyWkhECdvZbaWDOYmsSS2F9JLM0k9hDhJBSHA5_EMPykY5D44shL5ORAVJqHd3kJJPbycX1Svt7mJtuQZbP41ll8Qcvq2vUZZcubYUThl6NLALVyGOGGR078EhAaqHZrnfGMVcP1gQ6HOhk0GhRsfg62Yno2HHho-xYl3J6lxYRf-A',
#               'scope': 'GOOGLE',
#               'types': ['dentist',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '20390 Lorain Rd, Cleveland'}],
#  'status': 'OK'}

# %%
# 6. Bonus: Find the names and addresses of the top five restaurants in your home city.
#    Hint: Read about "Text Search Results"
# (https://developers.google.com/places/web-service/search#TextSearchRequests)
